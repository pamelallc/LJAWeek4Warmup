# %% [markdown]
# <a href="https://colab.research.google.com/github/pamelallc/LJAWeek4Warmup/blob/main/Copy_of_Week_1_Homework_(Pamela_Low).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Week 1 Homework
#
# (Be sure to save this to Drive before starting)
#
# For this week we are going to practice requesting information from an API and manipulating it as JSON and as a Dataframe.
#
# We are going to keep working with Collection Builder. Head over to the [Collection Builder Example Projects](https://collectionbuilder.github.io/cb-examples/browse.html) listing and find a site that interests you. Spend some time browsing the website to get acquainted with its contents before proceeding with the questions.

# %%
#The Libraries we will need
import requests
import json
import pandas as pd
from random import randrange

# %%
# @markdown **H1** Find the URL of for the  _metadata.json_ of your selected site and paste it in here.
json_cb_url = "https://uwtacomalibrary.github.io/TJLS/assets/data/metadata.json" # @param {"type":"string","placeholder":""}

response_cb = requests.get(json_cb_url)
#all of the data from the sites
total_cb_data = response_cb.json()
#just the 'objects' indexed in the site
objects_cb_data = total_cb_data['objects']
print("Data fetched and JSON constructed!")
# Out:
# Data fetched and JSON constructed!

# %% [markdown]
# **H2** Run the 'show random cell' a few times to get a sense of what kind of data is in your chosen site.

# %%
#Run this a few times to see random entries in the JSON data that you retrieved.
random_entry = randrange(len(objects_cb_data))
print(json.dumps(objects_cb_data[random_entry],indent=2))
# Out:
# {
#   "title": "Large group of students and adults in front of the Tacoma Japanese Language School gathered to celebrate the visit of Duke Tokugawa, March 4, 1934",
#   "creator": "Boland, M. D. (Marvin Dement)",
#   "date": "1934",
#   "description": "Written on photo in Japanese: SHoWA 9-NEN 3-GATSU 4-KA TOGUGAWA KoSHAKU KAKKA GOSHI KINEN SATUEI Translation: Commemorating the visit of his excellency Duke Tokugawa to Tacoma, WA on March 4, 1934. Handwritten on verso in Japanese: Fujimoto.",
#   "subject": "Japanese students--Washington (State)--Tacoma; School buildings--Washington (State)--Tacoma; Nihongo Gakko (Tacoma, Wash.)--Students; Portraits, Group--Washington (State)--Tacoma",
#   "location": "Tacoma, Washington, United States",
#   "source": "Photographs of the Tacoma Japanese Language School and Tacoma Hongwanji Buddhist Church. PH Coll 1021",
#   "type": "image",
#   "format": "image/jpeg",
#   "language": "eng",
#   "object_thumb": "https://digitalcollections.lib.washington.edu/digital/api/singleitem/image/panoram/117/default.jpg?highlightTerms=PH%20Coll%201020",
#   "object_location": "https://digitalcollections.lib.washington.edu/digital/iiif/panoram/117/full/full/0/default.jpg",
#   "reference_url": "erika-b.github.io/TJLS/items/largegroup1934.html"
# }

# %% [markdown]
# ## Different Fields!
#
# You can create any number of datafields and correpsonding values for those fields with a Collection Builder site. So the results from the output from the cell above will probably have wildly different results from [my site](https://elibtronic.github.io/AIL_Database/data.html) that we worked on in the Workalong notebook.
#
#
# You can see all of these options from grabbing the _facets.json_ URL from a collection builder homepage. Find that URL for your selected site for **H3**

# %%
# @markdown **H3** Find the URL of the facets.json for your selected site and paste it in here.
json_cb_facets_url = "https://uwtacomalibrary.github.io/TJLS/assets/data/facets.json" # @param {"type":"string","placeholder":""}

response_cb = requests.get(json_cb_facets_url)
#all of the data from the sites
total_facet_data = response_cb.json()
#just the 'objects' indexed in the site
print("Data fetched and JSON constructed!")
# Out:
# Data fetched and JSON constructed!

# %% [markdown]
# Run the cell below to see what the facets used for this site:

# %%
print(json.dumps(total_facet_data,indent=2))
#Why are other headings like Creator and Date not displayed? Are they not facets too?
# Out:
# {
#   "facets": [
#     {
#       "field": "subject",
#       "terms": {
#         "japanese students--washington (state)--tacoma": 3,
#         "school buildings--washington (state)--tacoma": 3,
#         "nihongo gakko (tacoma, wash.)--students": 3,
#         "portraits, group--washington (state)--tacoma": 2,
#         "nihongo gakko (tacoma, wash.)--faculty": 2,
#         "military officers--washington (state)--tacoma": 1
#       }
#     },
#     {
#       "field": "creator",
#       "terms": {
#         "boland, m. d. (marvin dement)": 3,
#         "hata, jack kazuo": 1,
#         "hattori, fumi (sato)": 1,
#         "horita, kazuo": 1,
#         "hayashi, june mieko (shirozu)": 1,
#         "takaoka, chizu": 1,
#         "takasugi, mitsuo": 1,
#         "taniguichi, taeko (hoshiwara)": 1,
#         "torimaru, hanna kae (nakagawa)": 1,
#         "yano, perry yoshiaki": 1,
#         "yoshioka, betty hiroko (fukuhara)": 1,
#         "chapin bowen inc.": 1,
#         "cysewski, stephen": 1,
#         "hoffman, lisa": 1,
#         "hanneman, mary": 1
#       }
#     },
#     {
#       "field": "format",
#       "terms": {
#         "image/jpeg": 16,
#         "compound_object": 10,
#         "csv": 1,
#         "audio/mp3": 1,
#         "video/mp4": 1
#       }
#     }
#   ]
# }

# %% [markdown]
# **H3** Try to read the JSON that is displayed to the screen. What possible facets are there in the the data. Fill them in the markdown list in the cell below. Add as many entries as you need to describe the site

# %% [markdown]
# Facets in my site are:
# - Subject
# - Creator
# - Format

# %% [markdown]
# **H4** Which facet shows up the most for your selected site? Put your answer in the cell below

# %% [markdown]
# This facet that shows up the most is Format it is used 29 times on my selected site.

# %% [markdown]
# **H5** Turn the site _metadata.json_ data into a dataframe by completing the cell below. Part of it is written for you. You just need to modify line 4.

# %%
#H5

cb_data = pd.read_json(json_cb_url)
cb_normalized = pd.json_normalize(cb_data['objects'])
cb_normalized
# Out:
#                                                 title  \
# 0                        Jack Kazuo Hata Oral History
# 1                               Jack Kazuo Hata image
# 2                    Fumi (Sato) Hattori Oral History
# 3                           Fumi (Sato) Hattori image
# 4                           Kazuo Horita Oral History
# 5                             Kazuo Horita transcript
# 6                                  Kazuo Horita audio
# 7                                  Kazuo Horita image
# 8           June Mieko (Shirozu) Hayashi Oral History
# 9                  June Mieko (Shirozu) Hayashi image
# 10                         Chizu Takaoka Oral History
# 11                                Chizu Takaoka image
# 12                       Mitsuo Takasugi Oral History
# 13                              Mitsuo Takasugi image
# 14          Taeko (Hoshiwara) Taniguichi Oral History
# 15                 Taeko (Hoshiwara) Taniguichi image
# 16         Hanna Kae (Nakagawa) Torimaru Oral History
# 17                Hanna Kae (Nakagawa) Torimaru image
# 18                   Perry Yoshiaki Yano Oral History
# 19                          Perry Yoshiaki Yano image
# 20      Betty Hiroko (Fukuhara) Yoshioka Oral History
# 21             Betty Hiroko (Fukuhara) Yoshioka image
# 22  Group of students and faculty outside the rear...
# 23  Large group of students and adults in front of...
# 24  Large group of students and faculty outside th...
# 25  Large group of students and faculty kneeling a...
# 26  Large group of students, faculty, and visiting...
# 27  Japanese Language School above Buddhist Temple...
# 28  Tacoma's Japanese Language School: An Oral His...
#
#                               creator                date  \
# 0                    Hata, Jack Kazuo          2005-01-30
# 1                                 NaN          2005-01-30
# 2                Hattori, Fumi (Sato)          2005-01-27
# 3                                 NaN          2005-01-27
# 4                       Horita, Kazuo          2005-03-11
# 5                                 NaN          2005-03-11
# 6                                 NaN          2005-03-11
# 7                                 NaN          2005-03-11
# 8       Hayashi, June Mieko (Shirozu)          2005-01-27
# 9                                 NaN          2005-01-29
# 10                     Takaoka, Chizu          2005-03-12
# 11                                NaN          2005-03-12
# 12                   Takasugi, Mitsuo          2005-01-09
# 13                                NaN          2005-01-09
# 14      Taniguichi, Taeko (Hoshiwara)          2006-03-17
# 15                                NaN          2006-03-17
# 16     Torimaru, Hanna Kae (Nakagawa)          2005-03-12
# 17                                NaN          2005-03-12
# 18               Yano, Perry Yoshiaki          2005-03-10
# 19                                NaN          2005-03-10
# 20  Yoshioka, Betty Hiroko (Fukuhara)          2005-03-10
# 21                                NaN          2005-03-10
# 22      Boland, M. D. (Marvin Dement)          1927-05-22
# 23      Boland, M. D. (Marvin Dement)                1934
# 24                  Chapin Bowen Inc.          1931-08-30
# 25                                NaN          1937-05-23
# 26      Boland, M. D. (Marvin Dement)  Approximately 1933
# 27                  Cysewski, Stephen                1979
# 28      Hoffman, Lisa; Hanneman, Mary                2012
#
#                                           description  \
# 0   Jack Kazuo Hata recounts his childhood growing...
# 1                                                 NaN
# 2   Fumi (Sato) Hattori looks back on her childhoo...
# 3                                                 NaN
# 4   Kazuo Horita shares his unique family history ...
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8   June Mieko (Shirozu) Hayashi traces her family...
# 9                                                 NaN
# 10  Chizu Takaoka traces her family history from J...
# 11                                                NaN
# 12  Mitsuo Takasugi reflects on his childhood grow...
# 13                                                NaN
# 14  Taeko Taniguishi Hoshiwara describes growing u...
# 15                                                NaN
# 16  Hanna Kae Nakagawa Torimaru recounts her famil...
# 17                                                NaN
# 18  Perry Yoshiaki Yano recounts his childhood in ...
# 19                                                NaN
# 20  Hiroko "Betty" Fukuhara Yoshioka describes her...
# 21                                                NaN
# 22  Written on photo: Tacoma Kokugo Gakko Kenchiku...
# 23  Written on photo in Japanese: SHoWA 9-NEN 3-GA...
# 24  Written in Japanese (translation): 20th annive...
# 25                         Handwritten on verso: HATA
# 26  Written on photo: Photograph commemorating the...
# 27                                  Looking northeast
# 28  Graduates of the Japanese Language School in T...
#
#                                              location  \
# 0   Los Angeles, California, United States; Toyama...
# 1                                                 NaN
# 2   Tacoma, Washington, United States; Ehime Prefe...
# 3                                                 NaN
# 4   Fukui Prefecture, Japan; Chicago, Illinois, Un...
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8   Altadena, California, United States; Longview,...
# 9                                                 NaN
# 10  Tacoma, Washington, United States; Fukushima, ...
# 11                                                NaN
# 12  Los Angeles, California, United States; Tacoma...
# 13                                                NaN
# 14  Seattle, Washington, United States; Honolulu, ...
# 15                                                NaN
# 16  Chicago, Illinois, United States; Tulelake, Ca...
# 17                                                NaN
# 18  Naperville, Illinois, United States; Tacoma, W...
# 19                                                NaN
# 20  Tacoma, Washington, United States; Chicago, Il...
# 21                                                NaN
# 22                  Tacoma, Washington, United States
# 23                  Tacoma, Washington, United States
# 24                  Tacoma, Washington, United States
# 25                  Tacoma, Washington, United States
# 26                  Tacoma, Washington, United States
# 27                  Tacoma, Washington, United States
# 28                  Tacoma, Washington, United States
#
#                                                people  \
# 0   Myer, Dillon; Heatter, Gabriel; Hata, Jack Kaz...
# 1                                                 NaN
# 2   Sato, Hidamaru; Sato, Masahiro; Sato, Toshiats...
# 3                                                 NaN
# 4   Ichio, Akiyo; Ikeda, Taki; Horita, Tom; Godfri...
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8   Isau, Mason (Shirozu); Reiko, Dorothy (Shirozu...
# 9                                                 NaN
# 10  Tomita, Tainojo; Nihei, Kin; Suzuki, Daise; Ho...
# 11                                                NaN
# 12  Emperor Meiji (Meiji the Great); Yamasaki, Mas...
# 13                                                NaN
# 14  Tanbara, Kimi; Taniguichi, Taeko (Hoshiwara); ...
# 15                                                NaN
# 16         Pei, I. M.; Torimaru, Hanna Kae (Nakagawa)
# 17                                                NaN
# 18  Hashimoto, Henry; Yamasaki, Masato; Yamasaki, ...
# 19                                                NaN
# 20  Yoshioka, Akiko (Iris); Yoshioka, Sada (Sally)...
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
#
#                                         organizations  \
# 0   Longfellow Elementary School; Morton M. McCarv...
# 1                                                 NaN
# 2   St. Paul Tacoma Lumber Company; Stadium High S...
# 3                                                 NaN
# 4   Tacoma Buddhist Temple; Whitney Memorial Unite...
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8   Central School; Japanese American National Mus...
# 9                                                 NaN
# 10  Central School; Morton M. McCarver Middle Scho...
# 11                                                NaN
# 12  Central School; Morton M. McCarver Middle Scho...
# 13                                                NaN
# 14  United States. War Relocation Authority; Rose ...
# 15                                                NaN
# 16  Tacoma Secretarial School; Central School; Lon...
# 17                                                NaN
# 18  Tacoma General Hospital; Central School; Stanl...
# 19                                                NaN
# 20  Central School; Morton M. McCarver Middle Scho...
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
#
#                                                places  \
# 0   Fawcett Avenue; Winthrop Hotel; Robert M. Smit...
# 1                                                 NaN
# 2                     St. Paul Avenue; Superior Hotel
# 3                                                 NaN
# 4                                  1124 Market Street
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8   Fawcett Avenue; Whitney Memorial United Method...
# 9                                                 NaN
# 10  Wright Park; Pearl Harbor; Tule Lake War Reloc...
# 11                                                NaN
# 12  Sheraton Hotel Tacoma (Hotel Murano); Washingt...
# 13                                                NaN
# 14  Traveler's Hotel; Pearl Harbor; Publix Hotel; ...
# 15                                                NaN
# 16  Tacoma City Hall; State Cafe (Furusato); Carlt...
# 17                                                NaN
# 18  Yao's Grocery; Fort Steilacoom; Point Defiance...
# 19                                                NaN
# 20                       Fawcett Avenue; Pearl Harbor
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
#
#                                                source               type  \
# 0             Tacoma Japanese Language School Project             record
# 1                                                 NaN   image;stillimage
# 2             Tacoma Japanese Language School Project             record
# 3                                                 NaN   image;stillimage
# 4             Tacoma Japanese Language School Project             record
# 5                                                 NaN               text
# 6                                                 NaN              sound
# 7                                                 NaN   image;stillimage
# 8             Tacoma Japanese Language School Project             record
# 9                                                 NaN   image;stillimage
# 10            Tacoma Japanese Language School Project             record
# 11                                                NaN   image;stillimage
# 12            Tacoma Japanese Language School Project             record
# 13                                                NaN   image;stillimage
# 14            Tacoma Japanese Language School Project             record
# 15                                                NaN   image;stillimage
# 16            Tacoma Japanese Language School Project             record
# 17                                                NaN   image;stillimage
# 18            Tacoma Japanese Language School Project             record
# 19                                                NaN   image;stillimage
# 20            Tacoma Japanese Language School Project             record
# 21                                                NaN   image;stillimage
# 22  Photographs of the Tacoma Japanese Language Sc...              image
# 23  Photographs of the Tacoma Japanese Language Sc...              image
# 24  Photographs of the Tacoma Japanese Language Sc...              image
# 25  Photographs of the Tacoma Japanese Language Sc...              image
# 26  Photographs of the Tacoma Japanese Language Sc...              image
# 27              Tacoma Public Library, Northwest Room              image
# 28                                          UW Tacoma  image;MovingImage
#
#              format language  \
# 0   compound_object      eng
# 1        image/jpeg      eng
# 2   compound_object      eng
# 3        image/jpeg      eng
# 4   compound_object      eng
# 5               csv      eng
# 6         audio/mp3      eng
# 7        image/jpeg      eng
# 8   compound_object      eng
# 9        image/jpeg      eng
# 10  compound_object      eng
# 11       image/jpeg      eng
# 12  compound_object      eng
# 13       image/jpeg      eng
# 14  compound_object      eng
# 15       image/jpeg      eng
# 16  compound_object      eng
# 17       image/jpeg      eng
# 18  compound_object      eng
# 19       image/jpeg      eng
# 20  compound_object      eng
# 21       image/jpeg      eng
# 22       image/jpeg      eng
# 23       image/jpeg      eng
# 24       image/jpeg      eng
# 25       image/jpeg      eng
# 26       image/jpeg      eng
# 27       image/jpeg      eng
# 28        video/mp4      eng
#
#                                                rights  \
# 0   This item is protected by copyright and/or rel...
# 1                                                 NaN
# 2   This item is protected by copyright and/or rel...
# 3                                                 NaN
# 4   This item is protected by copyright and/or rel...
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8   This item is protected by copyright and/or rel...
# 9                                                 NaN
# 10  This item is protected by copyright and/or rel...
# 11                                                NaN
# 12  This item is protected by copyright and/or rel...
# 13                                                NaN
# 14  This item is protected by copyright and/or rel...
# 15                                                NaN
# 16  This item is protected by copyright and/or rel...
# 17                                                NaN
# 18  This item is protected by copyright and/or rel...
# 19                                                NaN
# 20  This item is protected by copyright and/or rel...
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                               All rights reserved.
# 28                               All rights reserved.
#
#                                       rightsstatement  \
# 0      http://rightsstatements.org/vocab/InC-EDU/1.0/
# 1                                                 NaN
# 2      http://rightsstatements.org/vocab/InC-EDU/1.0/
# 3                                                 NaN
# 4      http://rightsstatements.org/vocab/InC-EDU/1.0/
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8      http://rightsstatements.org/vocab/InC-EDU/1.0/
# 9                                                 NaN
# 10  http://rightsstatements.org/page/InC-EDU/1.0/?...
# 11                                                NaN
# 12     http://rightsstatements.org/vocab/InC-EDU/1.0/
# 13                                                NaN
# 14     http://rightsstatements.org/vocab/InC-EDU/1.0/
# 15                                                NaN
# 16     http://rightsstatements.org/vocab/InC-EDU/1.0/
# 17                                                NaN
# 18     http://rightsstatements.org/vocab/InC-EDU/1.0/
# 19                                                NaN
# 20     http://rightsstatements.org/vocab/InC-EDU/1.0/
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27  Contact the Northwest Room at Tacoma Public Li...
# 28                                Contact UW Tacoma.
#
#                                          object_thumb  \
# 0   erika-b.github.io/TJLS/objects/thumbs/jhata_im...
# 1   erika-b.github.io/TJLS/objects/thumbs/jhata_im...
# 2   erika-b.github.io/TJLS/objects/thumbs/shattori...
# 3   erika-b.github.io/TJLS/objects/thumbs/shattori...
# 4   erika-b.github.io/TJLS/objects/thumbs/khorita_...
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8   erika-b.github.io/TJLS/objects/thumbs/jhayashi...
# 9   erika-b.github.io/TJLS/objects/thumbs/jhayashi...
# 10  erika-b.github.io/TJLS/objects/thumbs/ctakaoka...
# 11  erika-b.github.io/TJLS/objects/thumbs/ctakaoka...
# 12  erika-b.github.io/TJLS/objects/thumbs/mtakasug...
# 13  erika-b.github.io/TJLS/objects/thumbs/mtakasug...
# 14  erika-b.github.io/TJLS/objects/thumbs/ttanigui...
# 15  erika-b.github.io/TJLS/objects/thumbs/ttanigui...
# 16  erika-b.github.io/TJLS/objects/thumbs/htorimar...
# 17  erika-b.github.io/TJLS/objects/thumbs/htorimar...
# 18  erika-b.github.io/TJLS/objects/thumbs/pyoshiak...
# 19  erika-b.github.io/TJLS/objects/thumbs/pyoshiak...
# 20  erika-b.github.io/TJLS/objects/thumbs/hyoshiok...
# 21  erika-b.github.io/TJLS/objects/thumbs/hyoshiok...
# 22  https://digitalcollections.lib.washington.edu/...
# 23  https://digitalcollections.lib.washington.edu/...
# 24  https://digitalcollections.lib.washington.edu/...
# 25  https://digitalcollections.lib.washington.edu/...
# 26  https://digitalcollections.lib.washington.edu/...
# 27  https://digitalcollections.lib.washington.edu/...
# 28                                                NaN
#
#                                       object_location  \
# 0                        https://youtu.be/L1TiCeZoLTk
# 1      erika-b.github.io/TJLS/objects/jhata_image.jpg
# 2                        https://youtu.be/LdopnmPw9t4
# 3   erika-b.github.io/TJLS/objects/shattori_image.jpg
# 4
# 5          erika-b.github.io/TJLS/objects/khorita.csv
# 6   erika-b.github.io/TJLS/objects/khorita_audio_w...
# 7    erika-b.github.io/TJLS/objects/khorita_image.jpg
# 8                        https://youtu.be/N26x0Glv_us
# 9   erika-b.github.io/TJLS/objects/jhayashi_image.jpg
# 10                       https://youtu.be/s6N63V7uSK4
# 11  erika-b.github.io/TJLS/objects/ctakaoka_image.jpg
# 12                       https://youtu.be/Z0GmiEp4BtU
# 13  erika-b.github.io/TJLS/objects/mtakasugi_image...
# 14                       https://youtu.be/DJw4DUWVU-0
# 15  erika-b.github.io/TJLS/objects/ttaniguichi_ima...
# 16                       https://youtu.be/QBPnCDrNMW8
# 17  erika-b.github.io/TJLS/objects/htorimaru_image...
# 18                       https://youtu.be/qxDeh80UvT8
# 19  erika-b.github.io/TJLS/objects/pyoshiaki_image...
# 20                       https://youtu.be/25-tdb1QQNw
# 21  erika-b.github.io/TJLS/objects/hyoshioka_image...
# 22  https://digitalcollections.lib.washington.edu/...
# 23  https://digitalcollections.lib.washington.edu/...
# 24  https://digitalcollections.lib.washington.edu/...
# 25  https://digitalcollections.lib.washington.edu/...
# 26  https://digitalcollections.lib.washington.edu/...
# 27  https://digitalcollections.lib.washington.edu/...
# 28                       https://youtu.be/V_p8Zmz_nBk
#
#                                        reference_url  \
# 0            erika-b.github.io/TJLS/items/jhata.html
# 1           erika-b.github.io/TJLS/items/jhata2.html
# 2         erika-b.github.io/TJLS/items/shattori.html
# 3        erika-b.github.io/TJLS/items/shattori3.html
# 4          erika-b.github.io/TJLS/items/khorita.html
# 5         erika-b.github.io/TJLS/items/khorita1.html
# 6         erika-b.github.io/TJLS/items/khorita2.html
# 7         erika-b.github.io/TJLS/items/khorita3.html
# 8         erika-b.github.io/TJLS/items/jhayashi.html
# 9        erika-b.github.io/TJLS/items/jhayashi3.html
# 10        erika-b.github.io/TJLS/items/ctakaoka.html
# 11       erika-b.github.io/TJLS/items/ctakaoka3.html
# 12       erika-b.github.io/TJLS/items/mtakasugi.html
# 13      erika-b.github.io/TJLS/items/mtakasugi3.html
# 14     erika-b.github.io/TJLS/items/ttaniguichi.html
# 15    erika-b.github.io/TJLS/items/ttaniguichi3.html
# 16       erika-b.github.io/TJLS/items/htorimaru.html
# 17      erika-b.github.io/TJLS/items/htorimaru3.html
# 18       erika-b.github.io/TJLS/items/pyoshiaki.html
# 19      erika-b.github.io/TJLS/items/pyoshiaki3.html
# 20       erika-b.github.io/TJLS/items/hyoshioka.html
# 21      erika-b.github.io/TJLS/items/hyoshioka3.html
# 22  erika-b.github.io/TJLS/items/largegroup1927.html
# 23  erika-b.github.io/TJLS/items/largegroup1934.html
# 24  erika-b.github.io/TJLS/items/largegroup1931.html
# 25  erika-b.github.io/TJLS/items/largegroup1937.html
# 26  erika-b.github.io/TJLS/items/largegroup1933.html
# 27    erika-b.github.io/TJLS/items/building1979.html
# 28     erika-b.github.io/TJLS/items/booktrailer.html
#
#                                               subject
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23  Japanese students--Washington (State)--Tacoma;...
# 24                                                NaN
# 25  Japanese students--Washington (State)--Tacoma;...
# 26  Japanese students--Washington (State)--Tacoma;...
# 27                                                NaN
# 28                                                NaN

# %%
#Run this a few times to see random entries in your dataframe
cb_normalized.sample(10)
# Out:
#                                                 title  \
# 2                    Fumi (Sato) Hattori Oral History
# 16         Hanna Kae (Nakagawa) Torimaru Oral History
# 27  Japanese Language School above Buddhist Temple...
# 13                              Mitsuo Takasugi image
# 25  Large group of students and faculty kneeling a...
# 24  Large group of students and faculty outside th...
# 20      Betty Hiroko (Fukuhara) Yoshioka Oral History
# 15                 Taeko (Hoshiwara) Taniguichi image
# 3                           Fumi (Sato) Hattori image
# 10                         Chizu Takaoka Oral History
#
#                               creator        date  \
# 2                Hattori, Fumi (Sato)  2005-01-27
# 16     Torimaru, Hanna Kae (Nakagawa)  2005-03-12
# 27                  Cysewski, Stephen        1979
# 13                                NaN  2005-01-09
# 25                                NaN  1937-05-23
# 24                  Chapin Bowen Inc.  1931-08-30
# 20  Yoshioka, Betty Hiroko (Fukuhara)  2005-03-10
# 15                                NaN  2006-03-17
# 3                                 NaN  2005-01-27
# 10                     Takaoka, Chizu  2005-03-12
#
#                                           description  \
# 2   Fumi (Sato) Hattori looks back on her childhoo...
# 16  Hanna Kae Nakagawa Torimaru recounts her famil...
# 27                                  Looking northeast
# 13                                                NaN
# 25                         Handwritten on verso: HATA
# 24  Written in Japanese (translation): 20th annive...
# 20  Hiroko "Betty" Fukuhara Yoshioka describes her...
# 15                                                NaN
# 3                                                 NaN
# 10  Chizu Takaoka traces her family history from J...
#
#                                              location  \
# 2   Tacoma, Washington, United States; Ehime Prefe...
# 16  Chicago, Illinois, United States; Tulelake, Ca...
# 27                  Tacoma, Washington, United States
# 13                                                NaN
# 25                  Tacoma, Washington, United States
# 24                  Tacoma, Washington, United States
# 20  Tacoma, Washington, United States; Chicago, Il...
# 15                                                NaN
# 3                                                 NaN
# 10  Tacoma, Washington, United States; Fukushima, ...
#
#                                                people  \
# 2   Sato, Hidamaru; Sato, Masahiro; Sato, Toshiats...
# 16         Pei, I. M.; Torimaru, Hanna Kae (Nakagawa)
# 27                                                NaN
# 13                                                NaN
# 25                                                NaN
# 24                                                NaN
# 20  Yoshioka, Akiko (Iris); Yoshioka, Sada (Sally)...
# 15                                                NaN
# 3                                                 NaN
# 10  Tomita, Tainojo; Nihei, Kin; Suzuki, Daise; Ho...
#
#                                         organizations  \
# 2   St. Paul Tacoma Lumber Company; Stadium High S...
# 16  Tacoma Secretarial School; Central School; Lon...
# 27                                                NaN
# 13                                                NaN
# 25                                                NaN
# 24                                                NaN
# 20  Central School; Morton M. McCarver Middle Scho...
# 15                                                NaN
# 3                                                 NaN
# 10  Central School; Morton M. McCarver Middle Scho...
#
#                                                places  \
# 2                     St. Paul Avenue; Superior Hotel
# 16  Tacoma City Hall; State Cafe (Furusato); Carlt...
# 27                                                NaN
# 13                                                NaN
# 25                                                NaN
# 24                                                NaN
# 20                       Fawcett Avenue; Pearl Harbor
# 15                                                NaN
# 3                                                 NaN
# 10  Wright Park; Pearl Harbor; Tule Lake War Reloc...
#
#                                                source              type  \
# 2             Tacoma Japanese Language School Project            record
# 16            Tacoma Japanese Language School Project            record
# 27              Tacoma Public Library, Northwest Room             image
# 13                                                NaN  image;stillimage
# 25  Photographs of the Tacoma Japanese Language Sc...             image
# 24  Photographs of the Tacoma Japanese Language Sc...             image
# 20            Tacoma Japanese Language School Project            record
# 15                                                NaN  image;stillimage
# 3                                                 NaN  image;stillimage
# 10            Tacoma Japanese Language School Project            record
#
#              format language  \
# 2   compound_object      eng
# 16  compound_object      eng
# 27       image/jpeg      eng
# 13       image/jpeg      eng
# 25       image/jpeg      eng
# 24       image/jpeg      eng
# 20  compound_object      eng
# 15       image/jpeg      eng
# 3        image/jpeg      eng
# 10  compound_object      eng
#
#                                                rights  \
# 2   This item is protected by copyright and/or rel...
# 16  This item is protected by copyright and/or rel...
# 27                               All rights reserved.
# 13                                                NaN
# 25                                                NaN
# 24                                                NaN
# 20  This item is protected by copyright and/or rel...
# 15                                                NaN
# 3                                                 NaN
# 10  This item is protected by copyright and/or rel...
#
#                                       rightsstatement  \
# 2      http://rightsstatements.org/vocab/InC-EDU/1.0/
# 16     http://rightsstatements.org/vocab/InC-EDU/1.0/
# 27  Contact the Northwest Room at Tacoma Public Li...
# 13                                                NaN
# 25                                                NaN
# 24                                                NaN
# 20     http://rightsstatements.org/vocab/InC-EDU/1.0/
# 15                                                NaN
# 3                                                 NaN
# 10  http://rightsstatements.org/page/InC-EDU/1.0/?...
#
#                                          object_thumb  \
# 2   erika-b.github.io/TJLS/objects/thumbs/shattori...
# 16  erika-b.github.io/TJLS/objects/thumbs/htorimar...
# 27  https://digitalcollections.lib.washington.edu/...
# 13  erika-b.github.io/TJLS/objects/thumbs/mtakasug...
# 25  https://digitalcollections.lib.washington.edu/...
# 24  https://digitalcollections.lib.washington.edu/...
# 20  erika-b.github.io/TJLS/objects/thumbs/hyoshiok...
# 15  erika-b.github.io/TJLS/objects/thumbs/ttanigui...
# 3   erika-b.github.io/TJLS/objects/thumbs/shattori...
# 10  erika-b.github.io/TJLS/objects/thumbs/ctakaoka...
#
#                                       object_location  \
# 2                        https://youtu.be/LdopnmPw9t4
# 16                       https://youtu.be/QBPnCDrNMW8
# 27  https://digitalcollections.lib.washington.edu/...
# 13  erika-b.github.io/TJLS/objects/mtakasugi_image...
# 25  https://digitalcollections.lib.washington.edu/...
# 24  https://digitalcollections.lib.washington.edu/...
# 20                       https://youtu.be/25-tdb1QQNw
# 15  erika-b.github.io/TJLS/objects/ttaniguichi_ima...
# 3   erika-b.github.io/TJLS/objects/shattori_image.jpg
# 10                       https://youtu.be/s6N63V7uSK4
#
#                                        reference_url  \
# 2         erika-b.github.io/TJLS/items/shattori.html
# 16       erika-b.github.io/TJLS/items/htorimaru.html
# 27    erika-b.github.io/TJLS/items/building1979.html
# 13      erika-b.github.io/TJLS/items/mtakasugi3.html
# 25  erika-b.github.io/TJLS/items/largegroup1937.html
# 24  erika-b.github.io/TJLS/items/largegroup1931.html
# 20       erika-b.github.io/TJLS/items/hyoshioka.html
# 15    erika-b.github.io/TJLS/items/ttaniguichi3.html
# 3        erika-b.github.io/TJLS/items/shattori3.html
# 10        erika-b.github.io/TJLS/items/ctakaoka.html
#
#                                               subject
# 2                                                 NaN
# 16                                                NaN
# 27                                                NaN
# 13                                                NaN
# 25  Japanese students--Washington (State)--Tacoma;...
# 24                                                NaN
# 20                                                NaN
# 15                                                NaN
# 3                                                 NaN
# 10                                                NaN

# %% [markdown]
# **H6** This is for bonus!
# Try to write a pandas statement that will display your answer from **H4**. There are plenty of ways to do this, so feel free to use your imagination. What I have started for you here might not work, so feel free to change it as needed.

# %%
cb_normalized['format'].count()
print("The facet that shows up the most is Format. It is used {cb_normalized['format'].count()} times on the site.")

#I wanted to display the counts for all 3 facets in a table, so it's clear Format is most frequent.
#But why did "cb_normalized.groupby['facet'].count()" not work?
# Out:
# The facet that shows up the most is Format. It is used {cb_normalized['format'].count()} times on the site.

# %% [markdown]
# ## All Done!
#
# Congrats you are finished with this week's work. First save as PDF so that you can upload to the Course site then click the `Share` button above and enter `libraryjuicepresspython@gmail.com` so I can get a shared copy of your work.
